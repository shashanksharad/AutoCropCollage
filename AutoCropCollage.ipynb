# %% [markdown]
# # Automatically split collage of images into constituent images using OpenCV and Scipy

# %% [markdown]
# The AutoCropCollage package uses OpenCV and Scipy to split simple gridded collage of images into constituent images using edge detection

# %%
import cv2
import numpy as np
from scipy.signal import find_peaks
import matplotlib.pyplot as plt
from AutoCropCollage.AutoCropCollage import AutoCropCollage

# %%
atcp = AutoCropCollage()
atcp.split_collage('resources/collage.png')
